# %%
from map2loop.project import Project

proj = Project( geology_file="data/hams-test.shp",
                 fault_file="Turner_Syncline/tmp/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.csv",
                 structure_file="data/hams2_structure.shp",
                 mindep_file="data/mindeps_2018.shp")

proj.update_config(bbox_3d={
                         "minx": 500057,
                         "miny": 7455348,
                         "maxx": 603028,
                         "maxy": 7567953,
                         "base": -8200,
                         "top": 1200,
                     },
                     step_out=0.1
                  )

proj.run()
# Out:
# Input graphic saved to: model-test/tmp/input-fig.png
# Geology graphic exported to: model-test/tmp/geology.png
# Generating topology analyser input...
# 186  polygons
# 410  points
# 121  points
# 29  polylines
# KeyError: ('deposit_dist',)
# Resolving ambiguities using ASUD...	output_dir:model-test/graph
# Done.
# Generating topology graph display and unit groups...
# 0    'A-b-PRK', 'anchor': 'n', 'fontStyle': 'bold'
# 1    'A-mgn-PMI', 'anchor': 'n', 'fontStyle': 'bold'
# 2    'A-mgn-PRK', 'anchor': 'n', 'fontStyle': 'bold'
# 3    'A-s-PMI', 'anchor': 'n', 'fontStyle': 'bold'
# 4    'A-s-PRK', 'anchor': 'n', 'fontStyle': 'bold'
# 5    'Fortescue Group', 'anchor': 'n', 'fontStyle': 'bold'
# 6    'Hamersley Group', 'anchor': 'n', 'fontStyle': 'bold'
# 7    'Shingle Creek Group', 'anchor': 'n', 'fontStyle': 'bold'
# 8    'Turee Creek Group', 'anchor': 'n', 'fontStyle': 'bold'
# 9    'Wyloo Group', 'anchor': 'n', 'fontStyle': 'bold'
# 10    'A-FO-od'
# 11    'A-FO-xo-a'
# 12    'A-FOh-xs-f'
# 13    'A-FOj-xs-b'
# 14    'A-FOo-bbo'
# 15    'A-FOp-bs'
# 16    'A-FOr-b'
# 17    'A-FOu-bbo'
# 18    'A-HAS-xsl-ci'
# 19    'A-HAd-kd'
# 20    'A-HAm-cib'
# 21    'A-b-PRK'
# 22    'A-mgn-PMI'
# 23    'A-mgn-PRK'
# 24    'A-s-PMI'
# 25    'A-s-PRK'
# 26    'P_-HAb-cib'
# 27    'P_-HAj-xci-od'
# 28    'P_-HAo-ci'
# 29    'P_-HAw-fr'
# 30    'P_-SKb-bb'
# 31    'P_-SKq-stq'
# 32    'P_-TK-s'
# 33    'P_-TKa-xs-k'
# 34    'P_-TKk-sf'
# 35    'P_-TKo-stq'
# 36    'P_-WYa-st'
# 37    'P_-WYd-kd'
# 38    'P_-WYm-sp'
# Topology figure saved to model-test/tmp/topology-fig.png
# Done
# Fetching DTM...  bbox:116.90055218676851 118.10534844853859 -23.11022799089129 -21.88991765252865
# Attempt: 0
# /opt/conda/envs/m2l/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# dtm geotif saved as model-test/dtm/dtm.tif
# Done.
# reprojected dtm geotif saved as model-test/dtm/dtm_rp.tif
# /opt/conda/envs/m2l/lib/python3.7/site-packages/geopandas/tools/sjoin.py:61: UserWarning: CRS of frames being joined does not match!({'init': 'epsg:28350'} != {'init': 'EPSG:28350'})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: model-test/tmpgeol_clip.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-2-e9376f348b78> in <module>
#      17                   )
#      18
# ---> 19 proj.run()
#
# /map2loop-2/map2loop/project.py in run(self)
#     114         self.config.runMap2Model()
#     115         self.config.load_dtm()
# --> 116         self.config.join_features()
#     117
#     118         if(workflow['cover_map']):
#
# /map2loop-2/map2loop/config.py in join_features(self)
#     254         # Save geology clips
#     255         Topology.save_group(self.G, self.tmp_path,
# --> 256                             self.glabels, geol_clip, self.c_l)
#
# /map2loop-2/map2loop/topology.py in save_group(G, path_out, glabels, geol, c_l)
#     295         Gp = nx.Graph().to_directed()  # New Group graph
#     296
# --> 297         geology_file = gpd.read_file(path_out+'geol_clip.shp')
#     298
#     299         abs_age_groups(geol, path_out, c_l)
#
# /opt/conda/envs/m2l/lib/python3.7/site-packages/geopandas/io/file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
#      78             # In a future Fiona release the crs attribute of features will
#
# /opt/conda/envs/m2l/lib/python3.7/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     396     def wrapper(*args, **kwargs):
#     397         if local._env:
# --> 398             return f(*args, **kwargs)
#     399         else:
#     400             if isinstance(args[0], str):
#
# /opt/conda/envs/m2l/lib/python3.7/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     252         if mode in ('a', 'r'):
#     253             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 254                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     255         elif mode == 'w':
#     256             if schema:
#
# /opt/conda/envs/m2l/lib/python3.7/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     152             if self.mode == 'r':
#     153                 self.session = Session()
# --> 154                 self.session.start(self, **kwargs)
#     155             elif self.mode in ('a', 'w'):
#     156                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: model-test/tmpgeol_clip.shp: No such file or directory
