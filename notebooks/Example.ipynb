# %%
from maps.project import Project

# %%
proj = Project()
proj.update_config(bbox_3d={
                         "minx": 500057,
                         "maxx": 7455348,
                         "miny": 603028,
                         "maxy": 7567953,
                         "base": -8200,
                         "top": 1200,
                     },
                     step_out=0.1
                  )

# %%
proj.plot()

# %%
proj.config.update_parfile()
