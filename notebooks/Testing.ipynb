# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /opt/conda
# m2l                   *  /opt/conda/envs/m2l

# %%
# !conda list
# Out:
# # packages in environment at /opt/conda/envs/m2l:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# affine                    2.3.0                      py_0
# aiohttp                   3.6.2                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# asn1crypto                1.3.0                    py37_0
# async-timeout             3.0.1                    pypi_0    pypi
# attrs                     19.3.0                     py_0
# backcall                  0.1.0                    py37_0
# blas                      1.0                         mkl
# bleach                    3.1.4                      py_0
# bzip2                     1.0.8                h7b6447c_0
# ca-certificates           2020.1.1                      0
# cairo                     1.14.12              h8948797_3
# certifi                   2020.4.5.1               py37_0
# ...

# %%
from maps.project import Project

# %%
proj = Project()
proj.update_model(bbox_3d={
                         "minx": 500057,
                         "maxx": 7455348,
                         "miny": 603028,
                         "maxy": 7567953,
                         "base": -8200,
                         "top": 1200,
                     },
                     step_out=0.1
                  )

# %%
proj.plot_model()

# %%
proj.model.preprocess("export_csv")
# Out:
# 186  polygons
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8051ba2ea593> in <module>
# ----> 1 proj.model.preprocess("export_csv")
#
# /map2loop-2/maps/model.py in preprocess(self, command)
#      79                                  self.c_l['mst'], self.c_l['mtc'], self.c_l['mscm'], self.c_l['mcom']]]
#      80             Topology.save_mindep_wkt(
# ---> 81                 sub_mindep, self.mindep_file_csv, self.self.c_l)
#
# AttributeError: 'Model' object has no attribute 'self'

# %%
proj.model.geology_file_csv
# Out:
# './model-test/tmp/geology.csv'

# %%
import numpy as np
import pandas as pd

# %%
geoldf = pd.DataFrame(proj.model.geology_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a27aeb9cb473> in <module>
# ----> 1 geoldf = pd.DataFrame(proj.model.geology_file)
#
# /opt/conda/envs/m2l/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
geol_file = ".." + proj.model.geology_file[11:]
fault_file = ".." + proj.model.fault_file[11:]
mindep_file = ".." + proj.model.mindep_file[11:]

# %%
gdf = pd.read(geol_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-388a96b88714> in <module>
# ----> 1 gdf = pd.DataFrame(geol_file)
#
# /opt/conda/envs/m2l/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
# !pwd
# Out:
# /map2loop-2/notebooks

# %%
import geopandas as gpd
from maps.config import *
