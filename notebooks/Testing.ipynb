# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /opt/conda
# m2l                   *  /opt/conda/envs/m2l

# %%
# !conda list
# Out:
# # packages in environment at /opt/conda/envs/m2l:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# affine                    2.3.0                      py_0
# aiohttp                   3.6.2                    pypi_0    pypi
# appdirs                   1.4.4                    pypi_0    pypi
# asn1crypto                1.3.0                    py37_0
# async-timeout             3.0.1                    pypi_0    pypi
# attrs                     19.3.0                     py_0
# backcall                  0.1.0                    py37_0
# blas                      1.0                         mkl
# bleach                    3.1.4                      py_0
# bzip2                     1.0.8                h7b6447c_0
# ca-certificates           2020.1.1                      0
# cairo                     1.14.12              h8948797_3
# certifi                   2020.4.5.1               py37_0
# ...

# %%
from maps.project import Project

# %%
proj = Project()
proj.plot_roi()

# %%
# !pwd
# Out:
# /map2loop-2/notebooks

# %%
import geopandas as gpd
from maps.config import *

# %%
# geology_file="../maps/data/hams-test.shp"
# fault_file="../maps/data/GEOS_GEOLOGY_LINEARSTRUCTURE_500K_GSD.shp"
# structure_file="../maps/data/hams2_structure.shp"
# mindep_file="../maps/data/mindeps_2018.shp"
# bbox=(500057, 7455348, 603028, 7567953)

# geology = gpd.read_file(geology_file, bbox=bbox)
# lines=gpd.read_file(fault_file,bbox=bbox)
# structures = gpd.read_file(structure_file,bbox=bbox)

# base=geology.plot(column=c_l['c'],figsize=(10,10),edgecolor='#000000',linewidth=0.2)
# # structures.plot(ax=base, color='none',edgecolor='black')
# # lines.plot(ax=base,cmap='rainbow',column=c_l['f'],figsize=(10,10),linewidth=0.4)
# # polygon.plot(ax=base, color='none',edgecolor='black')

# %%
bbox={
 "minx": 500057,
 "maxx": 7455348,
 "miny": 603028,
 "maxy": 7567953,
 "base": -8200,
 "top": 1200,
}

# %%
minx, miny, maxx, maxy = list(bbox.values())[:4]

# %%
maxx
# Out:
# 603028
